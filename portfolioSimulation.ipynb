# %% [markdown]
# ## Portfolio Simulation with Monte Carlo

# %%
import sys
import os

sys.path.append('../monte-carlo-stock-portfolio-simulation/src')

from main import simulate
import datetime as dt


tickers = ["TQQQ", "QQQ", "SPY"]
end_date = dt.datetime.now()
start_date = end_date - dt.timedelta(days=10)
simulate(
    stocks=tickers, 
    startDate=start_date, 
    endDate=end_date,
    number_of_simulations=100,
    days=100,
    initial_portfolio_value=100
)
# Out:
# [*********************100%%**********************]  3 of 3 completed
